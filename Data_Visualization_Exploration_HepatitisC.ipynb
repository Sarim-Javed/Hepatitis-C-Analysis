# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Load the dataset
df = pd.read_csv('D:\SARIM\HepatitisCdata.csv')
df.head()  # Display the first few rows of the datasets
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            1
# ALP           18
# ALT            1
# AST            0
# BIL            0
# CHE            0
# CHOL          10
# CREA           0
# GGT            0
# PROT           1
# dtype: int64

# %%
# Fill missing values (example using mean)
df.fillna(df.mean(), inplace=True)
# Out:
# C:\Users\SARIM\AppData\Local\Temp\ipykernel_10780\2281217392.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
#check again nothing now missing values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Category      0
# Age           0
# Sex           0
# ALB           0
# ALP           0
# ALT           0
# AST           0
# BIL           0
# CHE           0
# CHOL          0
# CREA          0
# GGT           0
# PROT          0
# dtype: int64

# %%
# Convert categorical data to numerical (if necessary)
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
# Verify the changes
df.head()
# Out:
#    Unnamed: 0       Category  Age  Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32  NaN  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32  NaN  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32  NaN  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32  NaN  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32  NaN  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
# Descriptive statistics
df.describe()
# Out:
#        Unnamed: 0         Age  Sex         ALB         ALP         ALT  \
# count  615.000000  615.000000  0.0  615.000000  615.000000  615.000000
# mean   308.000000   47.408130  NaN   41.620195   68.283920   28.450814
# std    177.679487   10.055105  NaN    5.775920   25.643955   25.448940
# min      1.000000   19.000000  NaN   14.900000   11.300000    0.900000
# 25%    154.500000   39.000000  NaN   38.800000   52.950000   16.400000
# 50%    308.000000   47.000000  NaN   41.900000   66.700000   23.000000
# 75%    461.500000   54.000000  NaN   45.200000   79.300000   33.050000
# max    615.000000   77.000000  NaN   82.200000  416.600000  325.300000
#
#               AST         BIL         CHE        CHOL         CREA  \
# count  615.000000  615.000000  615.000000  615.000000   615.000000
# mean    34.786341   11.396748    8.196634    5.368099    81.287805
# std     33.090690   19.673150    2.205657    1.123466    49.756166
# ...

# %%
# Histograms
df.hist(bins=20, figsize=(20, 15))
plt.show()

# %%
# Correlation matrix
corr_matrix = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\SARIM\AppData\Local\Temp\ipykernel_10780\4003144932.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
# Pair plots
sns.pairplot(df)
plt.show()
